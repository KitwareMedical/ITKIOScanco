# %%
# Install notebook dependencies
import sys
# !{sys.executable} -m pip install itk-ioscanco tqdm pooch 'itkwidgets[all]>=1.0a21'

# %%
import pooch

from itkwidgets import view

import itk

# %%
file_name = 'C0004255.ISQ'
file_url = 'https://data.kitware.com/api/v1/file/591e56178d777f16d01e0d20/download'
file_sha256 = 'c2a3750c75826cb077d92093d43976cc0350198b55edecd681265eebabfb438b'
file_path = pooch.retrieve(file_url, file_sha256, fname=file_name, progressbar=True)

# %%
image = itk.imread(file_path)

# %%
view(image)
# Out:
#                 <img id="screenshot_imjoy_window_f4b14673-e3d2-44b7-85d1-a0ae59284dcd" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_f4b14673-e3d2-44b7-85d1-a0ae59284dcd");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_f4b14673-e3d2-44b7-85d1-a0ae59284dcd");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="0573edf5-64a2-4ea5-8f24-790d8745ae50"></div>
